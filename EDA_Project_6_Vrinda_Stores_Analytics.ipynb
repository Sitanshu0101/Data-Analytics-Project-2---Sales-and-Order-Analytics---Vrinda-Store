# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
path = "/content/Duplicate Vrinda Store Analysis - Vrinda Store (Analytics Project) - Vrinda Stores Dataset - Project.csv"
df = pd.read_csv(path)

# %% [markdown]
# # **Understanding the Dataset**

# %%
df.head()
# Out:
#    index             Order ID  Cust ID Gender  Age Age Group       Date Month  \
# 0      1  171-1029312-3038738  1029312  Women   44     Adult  12/4/2022   Dec
# 1      2  405-2183842-2225946  2183842  Women   29     Adult  12/4/2022   Dec
# 2      3  171-1641533-8921966  1641533  Women   67    Senior  12/4/2022   Dec
# 3      4  404-7490807-6300351  7490807  Women   20     Adult  12/4/2022   Dec
# 4      5  403-9293516-4577154  9293516  Women   62    Senior  12/4/2022   Dec
#
#       Status Channel  ... Qty currency Amount  Amount Figures  ship-city  \
# 0  Delivered  Myntra  ...   1      INR    376            1000     MOHALI
# 1  Delivered    Ajio  ...   1      INR   1449            2000   GURUGRAM
# 2  Delivered  Myntra  ...   1      INR    453            1000    KOLKATA
# 3  Delivered  Amazon  ...   1      INR    729            1000  THANJAVUR
# 4  Delivered  Myntra  ...   1      INR    544            1000   GURUGRAM
#
# ...

# %%
df.tail()
# Out:
#        index             Order ID  Cust ID Gender  Age Age Group      Date  \
# 31042  31043  405-4724097-1016369  4724097    Men   60    Senior  1/6/2022
# 31043  31044  405-4724097-1016369  4724097    Men   34     Adult  1/6/2022
# 31044  31045  408-3572295-5992330  3572295    Men   29     Adult  1/6/2022
# 31045  31046  405-1423498-9705162  1423498    Men   46     Adult  1/6/2022
# 31046  31047  408-4694875-8249153  4694875    Men   36     Adult  1/6/2022
#
#       Month     Status   Channel  ... Qty currency Amount  Amount Figures  \
# 31042   Jan  Delivered  Flipkart  ...   1      INR    565            1000
# 31043   Jan  Delivered    Myntra  ...   1      INR    939            1000
# 31044   Jan  Delivered    Amazon  ...   1      INR   1115            2000
# 31045   Jan  Delivered    Amazon  ...   1      INR    399            1000
# 31046   Jan  Delivered  Flipkart  ...   1      INR    791            1000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31047 entries, 0 to 31046
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             31047 non-null  int64
#  1   Order ID          31047 non-null  object
#  2   Cust ID           31047 non-null  int64
#  3   Gender            31047 non-null  object
#  4   Age               31047 non-null  int64
#  5   Age Group         31047 non-null  object
#  6   Date              31047 non-null  object
#  7   Month             31047 non-null  object
#  8   Status            31047 non-null  object
#  9   Channel           31047 non-null  object
#  10  SKU               31047 non-null  object
#  11  Category          31047 non-null  object
#  12  Size              31047 non-null  object
#  13  Qty               31047 non-null  int64
#  14  currency          31047 non-null  object
#  15  Amount            31047 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Cust ID', 'Gender', 'Age', 'Age Group', 'Date',
#        'Month', 'Status', 'Channel', 'SKU', 'Category', 'Size', 'Qty',
#        'currency', 'Amount', 'Amount Figures', 'ship-city', 'SHIP CITY',
#        'ship-state', 'ship-postal-code', 'ship-country', 'B2B'],
#       dtype='object')

# %%
df.describe()
# Out:
#              index       Cust ID           Age           Qty        Amount  \
# count  31047.00000  3.104700e+04  31047.000000  31047.000000  31047.000000
# mean   15524.00000  4.936824e+06     39.496570      1.006120    682.074822
# std     8962.64124  2.900678e+06     15.117233      0.094088    268.582173
# min        1.00000  8.950000e+02     18.000000      1.000000    229.000000
# 25%     7762.50000  2.416471e+06     28.000000      1.000000    486.000000
# 50%    15524.00000  4.909885e+06     37.000000      1.000000    646.000000
# 75%    23285.50000  7.454182e+06     47.000000      1.000000    794.000000
# max    31047.00000  9.999233e+06     78.000000      5.000000   3036.000000
#
#        Amount Figures  ship-postal-code
# count    31047.000000      31047.000000
# mean      1122.169614     460474.587206
# std        329.545877     198116.733009
# min       1000.000000     110001.000000
# 25%       1000.000000     313001.000000
# 50%       1000.000000     500028.000000
# ...

# %%
# Total unique figures present in our Dataset
df.nunique()
# Out:
# index               31047
# Order ID            28471
# Cust ID             28437
# Gender                  2
# Age                    61
# Age Group               2
# Date                   36
# Month                  12
# Status                  4
# Channel                 8
# SKU                  5287
# Category                8
# Size                   11
# Qty                     5
# currency                1
# Amount                769
# Amount Figures          3
# ship-city            2603
# SHIP CITY            1860
# ship-state             50
# ship-postal-code     4958
# ship-country            1
# B2B                     2
# dtype: int64

# %%
# Pointing the unique values within Age Group
df['Age Group'].unique()
# Out:
# array(['Adult', 'Senior'], dtype=object)

# %% [markdown]
# # **Data Cleaning and organising **

# %%
# This indicates that, Our Dataset has no null values
df.isnull().sum()
# Out:
# index               0
# Order ID            0
# Cust ID             0
# Gender              0
# Age                 0
# Age Group           0
# Date                0
# Month               0
# Status              0
# Channel             0
# SKU                 0
# Category            0
# Size                0
# Qty                 0
# currency            0
# Amount              0
# Amount Figures      0
# ship-city           0
# SHIP CITY           0
# ship-state          0
# ship-postal-code    0
# ship-country        0
# B2B                 0
# dtype: int64

# %%
# Dropping the useless Columns
ds = df.drop(['index', 'Cust ID', 'Date', 'SKU', 'Size', 'currency', 'ship-city', 'ship-postal-code', 'ship-country', 'B2B'], axis = 1)
ds.head()
# Out:
#               Order ID Gender  Age Age Group Month     Status Channel  \
# 0  171-1029312-3038738  Women   44     Adult   Dec  Delivered  Myntra
# 1  405-2183842-2225946  Women   29     Adult   Dec  Delivered    Ajio
# 2  171-1641533-8921966  Women   67    Senior   Dec  Delivered  Myntra
# 3  404-7490807-6300351  Women   20     Adult   Dec  Delivered  Amazon
# 4  403-9293516-4577154  Women   62    Senior   Dec  Delivered  Myntra
#
#   Category  Qty  Amount  Amount Figures  SHIP CITY   ship-state
# 0    kurta    1     376            1000     Mohali       PUNJAB
# 1      Set    1    1449            2000   Gurugram      HARYANA
# 2      Set    1     453            1000    Kolkata  WEST BENGAL
# 3      Set    1     729            1000  Thanjavur   TAMIL NADU
# 4    kurta    1     544            1000   Gurugram      HARYANA

# %%
# Just checking the outliers, as the data is correct during Excel analysis, thus, we do not have to remove them.

sns.boxplot(data = ds)
# Out:
# <Axes: >

# %% [markdown]
# ## **Data Analysis and Visulaization **

# %%
# Figuring out the interrelationship (Value - Oriented)
print('The co-relation will be - ', ds.corr())
sns.heatmap(ds.corr(), annot = True)
# Out:
# <ipython-input-13-d12ce64a1386>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('The co-relation will be - ', ds.corr())
# <ipython-input-13-d12ce64a1386>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(ds.corr(), annot = True)
# The co-relation will be -                       Age       Qty    Amount  Amount Figures
# Age             1.000000  0.004884  0.003522       -0.004581
# Qty             0.004884  1.000000  0.172377        0.138982
# Amount          0.003522  0.172377  1.000000        0.748128
# Amount Figures -0.004581  0.138982  0.748128        1.000000
# <Axes: >

# %%
# Analysing Sales amount in comparision with Age group
sns.countplot(data = ds, x = 'Amount Figures', hue = 'Age Group')
# Out:
# <Axes: xlabel='Amount Figures', ylabel='count'>

# %%
# Analysing Sales amount in comparision with Gender
sns.countplot(data = ds, x = 'Amount Figures', hue = 'Gender')
# Out:
# <Axes: xlabel='Amount Figures', ylabel='count'>

# %%
# Analysing Sales amount in comparision with Category
sns.countplot(data = ds, x = 'Amount Figures', hue = 'Category')
# Out:
# <Axes: xlabel='Amount Figures', ylabel='count'>

# %%
# Analysing Sales amount in comparision with Channel
sns.countplot(data = ds, x = 'Amount Figures', hue = 'Channel')
# Out:
# <Axes: xlabel='Amount Figures', ylabel='count'>

# %%
# Relationship between Age and Sales Amount with respect to gender
sns.relplot(data = ds, x = 'Amount', y = 'Age', hue = 'Gender' )

# %%
# Relationship between Age and Sales Amount with respect to Channel
sns.barplot(data = ds, x = 'Amount Figures', y = 'Age', hue = 'Channel')
# Out:
# <Axes: xlabel='Amount Figures', ylabel='Age'>

# %%
# Analysing Sales amount in comparision with Age group
sns.countplot(data = ds, x = 'Amount Figures', hue = 'ship-state')
# Out:
# <Axes: xlabel='Amount Figures', ylabel='count'>

# %%
# Jointplot visualization of Amount Figures and Age with respect to Channel
sns.jointplot(data = ds, x = 'Amount Figures', y = 'Age', hue = 'Channel' )

# %%
# Jointplot visualization of Amount Figures and Age with respect to Category
sns.jointplot(data = ds, x = 'Amount Figures', y = 'Age', hue = 'Category')

# %%
# Jointplot visualization of Amount Figures and Age with respect to Gender
sns.jointplot(data = ds, x = 'Amount Figures', y = 'Age', hue = 'Gender')

# %%
# Jointplot visualization of Amount Figures and Age with respect to Gender
sns.jointplot(data = ds, x = 'Amount Figures', y = 'Age', hue = 'Status')

# %%
# Jointplot visualization of Amount Figures and Age with respect to Shipping state
sns.jointplot(data = ds, x = 'Amount Figures', y = 'Age', hue = 'ship-state', palette = 'rainbow')

# %%
# Boxplot
sns.boxplot(data = ds, x = 'Amount Figures', y = 'Age', hue = 'Category')
# Out:
# <Axes: xlabel='Amount Figures', ylabel='Age'>

# %%
# Boxplot
sns.boxplot(data = ds, x = 'Amount Figures', y = 'Age', hue = 'Channel')
# Out:
# <Axes: xlabel='Amount Figures', ylabel='Age'>

# %%
# Boxplot
sns.boxplot(data = ds, x = 'Amount Figures', y = 'Age', hue = 'Gender')
# Out:
# <Axes: xlabel='Amount Figures', ylabel='Age'>

# %%
# Violinplot
sns.violinplot(data = ds, x = 'Amount Figures', y = 'Age', hue = 'Status')
# Out:
# <Axes: xlabel='Amount Figures', ylabel='Age'>

# %%
sns.pairplot(data = ds, hue = 'Gender')
